# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
mitre_json = r"C:\Users\jagua\OneDrive\Documentos\Diplomado IA y TA\Modulo 4  Proyecto Integrador\ciber_monitoring\data_engineering\bronze\cve_mitre_raw_2026-01-05T21-23-05.372412.json"
nvidia_json = r"C:\Users\jagua\OneDrive\Documentos\Diplomado IA y TA\Modulo 4  Proyecto Integrador\ciber_monitoring\data_engineering\bronze\nvidia_raw_2026-01-05T21-30-32.334959.json"
openai_json = r"C:\Users\jagua\OneDrive\Documentos\Diplomado IA y TA\Modulo 4  Proyecto Integrador\ciber_monitoring\data_engineering\bronze\openai_raw_2026-01-05T21-31-58.592886.json"
x_json = r"C:\Users\jagua\OneDrive\Documentos\Diplomado IA y TA\Modulo 4  Proyecto Integrador\ciber_monitoring\data_engineering\bronze\twitter_raw_2026-01-05T21-22-44.857929.json"

# %%
with open(mitre_json) as archivo:
    datos_diccionario = json.load(archivo)

# %%
print(datos_diccionario)
# Out:
# {'metadata': {'source': 'cve_mitre', 'timestamp': '2026-01-05T21:23:05.372961', 'record_count': 204}, 'data': [{'cve_id': 'CVE-2025-68669', 'source_url': 'https://www.cve.org/CVERecord?id=CVE-2025-68669', 'description': '5ire is a cross-platform desktop artificial intelligence assistant and model context protocol client. In versions 0.15.2 and prior, an RCE vulnerability exists in useMarkdown.ts, where the markdown-it-mermaid plugin is initialized...', 'keyword_matched': 'artificial intelligence', 'severity': 'UNKNOWN', 'published_date': 'UNKNOWN', 'affected_products': []}, {'cve_id': 'CVE-2025-68669', 'source_url': 'https://www.cve.org/CVERecord?id=CVE-2025-68669', 'description': '5ire is a cross-platform desktop artificial intelligence assistant and model context protocol client. In versions 0.15.2 and prior, an RCE vulnerability exists in useMarkdown.ts, where the markdown-it-mermaid plugin is initialized...', 'keyword_matched': 'artificial intelligence', 'severity': 'UNKNOWN', 'p
# ...

# %%
datos_diccionario['data']
# Out:
# [{'cve_id': 'CVE-2025-68669',
#   'source_url': 'https://www.cve.org/CVERecord?id=CVE-2025-68669',
#   'description': '5ire is a cross-platform desktop artificial intelligence assistant and model context protocol client. In versions 0.15.2 and prior, an RCE vulnerability exists in useMarkdown.ts, where the markdown-it-mermaid plugin is initialized...',
#   'keyword_matched': 'artificial intelligence',
#   'severity': 'UNKNOWN',
#   'published_date': 'UNKNOWN',
#   'affected_products': []},
#  {'cve_id': 'CVE-2025-68669',
#   'source_url': 'https://www.cve.org/CVERecord?id=CVE-2025-68669',
#   'description': '5ire is a cross-platform desktop artificial intelligence assistant and model context protocol client. In versions 0.15.2 and prior, an RCE vulnerability exists in useMarkdown.ts, where the markdown-it-mermaid plugin is initialized...',
#   'keyword_matched': 'artificial intelligence',
#   'severity': 'UNKNOWN',
#   'published_date': 'UNKNOWN',
#   'affected_products': []},
# ...
